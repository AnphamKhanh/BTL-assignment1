# %% [markdown]
# # Hồi quy Ridge (gradient descent)

# %% [markdown]
# Trong notebook này, chúng ta sẽ triển khai hồi quy Ridge qua gradient descent. Chúng ta sẽ:
# * Trích xuất các giá trị DataFrame thành mảng Numpy.
# * Viết hàm Numpy để tính đạo hàm của các trọng số hồi quy với một đặc trung duy nhất.
# * Viết hàm gradient descent để tính các trọng số hồi quy biết vectơ trọng số ban đầu, kích thước bước, dung sai và L2 penalty.

# %% [markdown]
# ## Như thường lệ

# %%
import sklearn
import pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load dữ liệu doanh số bán nhà
# Tập dữ liệu doanh số bán nhà ở quận King, Seatle, WA. Nghe quen chứ?

# %%
full_data = pandas.read_csv("/content/drive/MyDrive/Colab_Notebooks/Bai tap lap/Mon_hoc_2/kc_house_data.csv", index_col=0)

# %% [markdown]
# Nếu muốn thực hiện bất kỳ "feature engineering" nào như tạo các đặc trưng mới hoặc điều chỉnh đặc trưng sẵn có, chúng ta có thể sửa DataFrame của pandas như trong lab trước (Lab 2). Tuy nhiên, với notebook này, chúng ta sẽ làm việc với các đặc trưng có sẵn.

# %% [markdown]
# ## Import các hàm hữu ích từ notebook trước

# %% [markdown]
# Như trong Lab trước, chúng ta chuyển đổi DataFrame thành ma trận Numpy 2D. Copy và paste `get_numpy_data()` từ notebook Lab 2.

# %%
import numpy as np # điều này cho phép gọi numpy as np

# %%
def get_numpy_data(data, features_title, output_title):
    if('constant' not in data):
        data['constant'] = 1 # đây là cách thêm cột constant. Chỉ thực hiện khi cần
    # thêm cột 'constant' vào trước list các đặc trưng để chúng ta có thể trích xuất cùng với những thứ khác:
    features_title = ['constant'] + features_title # đây là cách kết hợp 2 list
    # chia dữ liệu thành sub-DataFrame chứa các đặc trưng đã chỉ định (gồm constant)
    # gọi nó là features_columns.
    features_columns = data[features_title]
    # dòng tiếp theo sẽ trích xuất ma trận numpy từ biến features_columns:
    feature_matrix = features_columns.values
    # truy xuất dữ liệu được liên kết với đầu ra trong pandas Series
    # gọi nó là output_column
    output_column = data[output_title]
    # tiếp theo sẽ chuyển đổi Series đã nhắc thành một mảng numpy
    output_array = output_column.values
    return(feature_matrix, output_array)

# %% [markdown]
# Cũng copy và paste cả hàm `predict_output()` để tính các dự đoán cho toàn bộ ma trận đặc trưng với ma trận và trọng số đã cho:

# %%
def predict_output(features, weights):
    # giả sử ma trận feature_matrix chứa các đặc trưng ở dạng các cột và trọng số là mảng numpy tương ứng
    # tạo vectơ dự đoán sử dụng np.dot()
    predictions = features@(weights.T)
    return(predictions)

# %% [markdown]
# ## Tính đạo hàm

# %% [markdown]
# Bây giờ chúng ta sẽ chuyển sang tính đạo hàm của hàm chi phí hồi quy. Hàm chi phí là tổng các điểm dữ liệu của bình phương của hiệu giữa kết quả quan sát và kết quả dự đoán cộng với L2 penalty.
# <!-- ``` Cost(w) = SUM[ (prediction - output)^2 ] + l2_penalty*(w[0]^2 + w[1]^2 + ... + w[k]^2). ``` This is commented out. -->
# $ cost_w = \sum (prediction - output)^2 + l2\_penalty * \sum_i w_i^2 $ (trong đó $w_0$ là độ chệch)
#
# Vì đạo hàm của một tổng là tổng các đạo hàm nên chúng ta có thể tính đạo hàm của phần đầu tiên (RSS) như đã thực hiện trong notebook về trường hợp được điều chuẩn và cộng đạo hàm của phần điều chuẩn. Chúng ta có thể viết đạo hàm với $w_i$(`w[i]`)  như sau:
# <!-- ``` 2*SUM[ error*[feature_i] ]. ``` -->
# $ 2 * \sum error * feature_i $
#
# Đạo hàm của phần điều chuẩn với $w_i$ là:
# <!-- ``` 2*l2_penalty*w[i]. ``` -->
# $ 2 * l2\_penalty * w_i $
#
# Cộng cả 2 lại, chúng ta được:
# <!-- ``` 2*SUM[ error*[feature_i] ] + 2*l2_penalty*w[i]. ``` -->
# $ 2 * \sum error * feature_i + 2 * l2\_penalty * w_i $
#
# Đây là đạo hàm cho trọng số của đặc trưng i, là tổng (trên các điểm dữ liệu) của 2 nhân với tích của sai số và chính đặc trưng cộng với `2*l2_penalty*w[i]`.
#
# **Chúng ta sẽ không điều chuẩn hóa hằng số.**  Do đó, trong trường hợp hằng số thì đạo hàm sẽ bằng 2 lần tổng các sai số (không có phần tử `2*l2_penalty*w[0]`).
#
# 2 lần tổng của tích hai vectơ chỉ là hai nhân tích của hai vectơ. Do đó, đạo hàm cho trọng số của $feature_i$ bằng hai lần tích vô hướng giữa các giá trị $feature_i$ và sai số hiện tại cộng với $2*l2\_penalty*w_i$.
#
#
# Hãy hoàn thành hàm đạo hàm sau đây để tính đạo hàm của trọng số cho giá trị của đặc trưng (trên tất cả các điểm dữ liệu) và sai số (trên tất cả các điểm dữ liệu). Để quyết định khi nào thì xử lý hằng số (chúng ta không điều chuẩn nó), chúng ta thêm tham số bổ sung để gọi `feature_is_constant` đặt thành `True` khi tính đạo hàm của hằng số và `False` nếu không phải.

# %%
def feature_derivative_ridge(errors, feature, weight, l2_penalty, feature_is_constant):
    # Nếu feature_is_constant là True thì đạo hàm bằng 2 nhân tích vô hướng của sai số và đặc trưng
    if (feature_is_constant):
        derivative = 2*errors@feature
    # Nếu không, đạo hàm bằng 2 nhân tích vô hướng cộng với 2*l2_penalty*weight
    else:
        derivative = 2*errors@feature + 2*l2_penalty*weight
    return derivative

# %% [markdown]
# Để kiểm tra đạo hàm, chạy cell sau:

# %%
(example_features, example_output) = get_numpy_data(full_data, ['sqft_living'], 'price')
my_weights = np.array([1., 10.])
test_predictions = predict_output(example_features, my_weights)
errors = test_predictions - example_output # các sai số dự đoán

# 2 dòng tiếp theo in các giá trị tương tự
print(feature_derivative_ridge(errors, example_features[:,1], my_weights[1], 1, False))
print(np.sum(errors*example_features[:,1])*2+20.)

print("-------")
# 2 dòng tiếp theo in các giá trị tương tự
print(feature_derivative_ridge(errors, example_features[:,0], my_weights[0], 1, True))
print(np.sum(errors)*2.0)
# Out:
# -56554166815950.0
# -56554166815950.0
# -------
# -22446749330.0
# -22446749330.0

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# Bây giờ chúng ta sẽ viết một hàm thực hiện gradient descent. Tiền đề cơ bản khá đơn giản. Với một điểm bắt đầu, chúng ta cập nhật các trọng số hiện tại bằng cách di chuyển theo hướng gradient âm. Gradient có hướng *tăng* nên gradient âm có hướng *giảm* và chúng ta đang cố gắng *giảm thiểu* hàm chi phí.
#
#
# Lượng mà chúng ta di chuyển theo *hướng* gradient âm được gọi là 'kích thước bước'. Chúng ta dừng lại khi chúng ta 'đủ gần' với mức tối ưu. Không giống lần trước, lần này chúng ta sẽ đặt **số lần lặp tối đa** và thực hiện các bước gradient cho tới khi đạt tới số lượng tối đa này. Nếu không cấp số lượng tối đa thì max sẽ được đặt mặc định là 100 (Sử dụng các giá trị tham số mặc định trong Python).
#
# Hãy hoàn thành hàm gradient descent sau bằng cách sử dụng hàm đạo hàm ở trên. Với mỗi bước trong gradient descent, chúng ta cập nhật trọng số cho từng đặc trưng trước khi tính tiêu chí dừng.

# %%
def ridge_regression_gradient_descent(feature_matrix, output, initial_weights, step_size, l2_penalty, max_iterations=100):
    print('Starting gradient descent with l2_penalty = ' + str(l2_penalty))

    weights = np.array(initial_weights) # đảm bảo đây là một mảng numpy
    iteration = 0 # bộ đếm lặp
    print_frequency = 1  # điều chỉnh tần suất của đầu ra gỡ lỗi
    while(iteration <= max_iterations):
    #khi không đạt tới lượng lặp tối đa:
        iteration += 1  # tăng bộ đếm lặp
        ### === phần code điều chỉnh tần suất của đầu ra gỡ lỗi. ===
        if iteration == 10:
            print_frequency = 10
        if iteration == 100:
            print_frequency = 100
        if iteration%print_frequency==0:
            print('Iteration = ' + str(iteration))
        ### === kết thúc phần code ===

        # tính các dự đoán dựa trên on feature_matrix và các trọng số sử dụng hàm predict_output()
        predict_values = predict_output(feature_matrix, weights)
        # tính sai số dưới dạng dự đoán - đầu ra
        errors = predict_values - output
        # thi thoảng in ra giá trị hàm chi phí
        if iteration%print_frequency==0:
            print('Cost function = ', str(np.dot(errors,errors) + l2_penalty*(np.dot(weights,weights) - weights[0]**2)))

        for i in range(len(weights)): # lặp qua từng đặc trưng
            # feature_matrix[:,i] là cột đặc trưng liên kết với weights[i]
            # tính đạo hàm cho weight[i].
            #(Nhớ rằng: khi i=0, chúng ta sẽ tính đạo hàm của hằng số!)
            if i ==0:
                derivative_cal = feature_derivative_ridge(errors, feature_matrix[:,i], weights[i], l2_penalty, True)

            else:
                derivative_cal = feature_derivative_ridge(errors, feature_matrix[:,i], weights[i], l2_penalty, False)

             # trừ kích thước bước nhân với đạo hàm từ trọng số hiện tại
            weights[i] = weights[i] - step_size*derivative_cal
    print('Done with gradient descent at iteration ', iteration)
    print('Learned weights = ', str(weights))
    return weights

# %%
"""
from sklearn.model_selection import train_test_split
train_and_validation, test_data = train_test_split(full_data, train_size=0.9, test_size=0.1, random_state=1)
train_and_validation = sklearn.utils.shuffle(train_and_validation, random_state=1)

# %%
"""  ===================>>>>>>>>>>>>>>>>>>. lamf khong ra, đang cố làm trường hợp của bài lap poly function bằng gradient descent
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler

def poly_datafrmae(feature, degree):
    data = pandas.DataFrame()
    for i in range(1, (degree+1)):
        name = 'poly_' + str(i)
        data[name] = feature**i
    return data
degree =15
feature_title = []
for i in range(1, (degree+1)):
    name = 'poly_' + str(i)
    feature_title.append(name)

data_train_create = poly_datafrmae(full_data['sqft_living'],15)
scaler = StandardScaler()
mm = scaler.fit_transform(data_train_create.values)
data_train_create = pandas.DataFrame(data=mm, columns=feature_title)
print(data_train_create)
data_train_create['price'] = full_data['price'].values
(matrix_feature, oupt_feature) = get_numpy_data(data_train_create, feature_title, 'price')

initial_weights = np.array([0., 30000., 162000., 200000., -170000., -14000., -1000., -1300., 2100., -1600., -1600., 19000., 5000., 700., -1600., 300.])
step_size = 1e-10
max_iterations=1000

l2_penalty = float(10**1.5)
simple_weights_0_penalty = ridge_regression_gradient_descent(matrix_feature, oupt_feature, initial_weights, step_size, l2_penalty, 100000)
# Out:
#          poly_1    poly_2    poly_3    poly_4    poly_5    poly_6    poly_7  \
# 0     -0.979835 -0.698601 -0.379979 -0.160060 -0.252826  0.453600 -1.004648
# 1      0.533634  0.265493  0.043471 -0.036537 -0.074538 -1.486663  0.844570
# 2     -1.426254 -0.846475 -0.412749 -0.164763 -0.256101 -0.044147 -0.952101
# 3     -0.130550 -0.245602 -0.217397 -0.122075 -0.209584  0.184684 -0.494112
# 4     -0.435422 -0.434111 -0.294397 -0.142200 -0.234815  0.720699 -1.299187
# ...         ...       ...       ...       ...       ...       ...       ...
# 21608 -0.598746 -0.523168 -0.326437 -0.149567 -0.242930 -1.208522 -0.086052
# 21609  0.250539  0.030818 -0.084910 -0.081432 -0.149765  0.786562 -0.849830
# 21610 -1.154047 -0.763707 -0.396049 -0.162598 -0.254748  0.139224  1.041521
# 21611 -0.522528 -0.482644 -0.312229 -0.146385 -0.239518 -0.419376  0.765948
# 21612 -1.154047 -0.763707 -0.396049 -0.162598 -0.254748  0.139224  1.041521
#
#          poly_8    poly_9   poly_10   poly_11   poly_12   poly_13   poly_14  \
# 0      0.535314 -1.599793  0.025210 -1.436867  1.439134 -0.167402  1.248572
# 1      0.072098 -0.355384 -0.829351 -0.883748 -0.302104 -0.833700  0.635860
# 2     -0.237372 -0.975090 -0.939062 -0.735471  1.015355  0.235182  1.404912
# 3     -1.050824  0.585323 -0.247379  0.369681 -0.477798  0.669901 -1.435483
# 4      0.035040 -0.898801  0.644882 -1.020147 -0.166224  0.162543  1.641165
# ...         ...       ...       ...       ...       ...       ...       ...
# 21608  0.072227  1.433263  0.887320 -0.462420  0.357698 -0.600301 -1.495142
# 21609  1.400990  0.519144  0.954481 -0.642888  1.152005  0.281749  0.731333
# 21610 -0.776440 -0.086781  1.045022  0.733050 -0.210638 -0.617542  1.760516
# 21611  1.462105  1.565839  0.197368  0.112593  0.034370 -0.025559  0.010802
# 21612 -0.776440 -0.086781  1.045022  0.733050 -0.210638 -0.617542  1.760516
#
#         poly_15
# 0      1.489528
# 1     -0.344157
# 2     -1.360791
# 3     -1.736140
# 4     -1.603196
# ...         ...
# 21608  0.607134
# 21609 -1.369446
# 21610  0.632826
# 21611 -0.053933
# 21612  0.632826
#
# [21613 rows x 15 columns]
# Starting gradient descent with l2_penalty = 31.622776601683793
# Iteration = 1
# Cost function =  7657182642867523.0
# Iteration = 2
# Cost function =  7657127814495832.0
# Iteration = 3
# Cost function =  7657072986603830.0
# Iteration = 4
# Cost function =  7657018159191512.0
# Iteration = 5
# Cost function =  7656963332258873.0
# Iteration = 6
# Cost function =  7656908505805908.0
# Iteration = 7
# Cost function =  7656853679832614.0
# Iteration = 8
# Cost function =  7656798854338985.0
# Iteration = 9
# Cost function =  7656744029325020.0
# Iteration = 10
# Cost function =  7656689204790711.0
# Iteration = 20
# Cost function =  7656140985827816.0
# Iteration = 30
# Cost function =  7655592814825903.0
# Iteration = 40
# Cost function =  7655044691780652.0
# Iteration = 50
# Cost function =  7654496616687739.0
# Iteration = 60
# Cost function =  7653948589542854.0
# Iteration = 70
# Cost function =  7653400610341674.0
# Iteration = 80
# Cost function =  7652852679079882.0
# Iteration = 90
# Cost function =  7652304795753161.0
# Iteration = 100
# Cost function =  7651756960357198.0
# Iteration = 200
# Cost function =  7646281241639826.0
# Iteration = 300
# Cost function =  7640810311253134.0
# Iteration = 400
# Cost function =  7635344164887716.0
# Iteration = 500
# Cost function =  7629882798238420.0
# Iteration = 600
# Cost function =  7624426207004327.0
# Iteration = 700
# Cost function =  7618974386888759.0
# Iteration = 800
# Cost function =  7613527333599265.0
# Iteration = 900
# Cost function =  7608085042847622.0
# Iteration = 1000
# Cost function =  7602647510349818.0
# Iteration = 1100
# Cost function =  7597214731826064.0
# Iteration = 1200
# Cost function =  7591786703000774.0
# Iteration = 1300
# Cost function =  7586363419602572.0
# Iteration = 1400
# Cost function =  7580944877364277.0
# Iteration = 1500
# Cost function =  7575531072022896.0
# Iteration = 1600
# Cost function =  7570121999319637.0
# Iteration = 1700
# Cost function =  7564717654999880.0
# Iteration = 1800
# Cost function =  7559318034813190.0
# Iteration = 1900
# Cost function =  7553923134513301.0
# Iteration = 2000
# Cost function =  7548532949858117.0
# Iteration = 2100
# Cost function =  7543147476609703.0
# Iteration = 2200
# Cost function =  7537766710534282.0
# Iteration = 2300
# Cost function =  7532390647402223.0
# Iteration = 2400
# Cost function =  7527019282988062.0
# Iteration = 2500
# Cost function =  7521652613070455.0
# Iteration = 2600
# Cost function =  7516290633432206.0
# Iteration = 2700
# Cost function =  7510933339860252.0
# Iteration = 2800
# Cost function =  7505580728145650.0
# Iteration = 2900
# Cost function =  7500232794083586.0
# Iteration = 3000
# Cost function =  7494889533473360.0
# Iteration = 3100
# Cost function =  7489550942118385.0
# Iteration = 3200
# Cost function =  7484217015826184.0
# Iteration = 3300
# Cost function =  7478887750408374.0
# Iteration = 3400
# Cost function =  7473563141680672.0
# Iteration = 3500
# Cost function =  7468243185462890.0
# Iteration = 3600
# Cost function =  7462927877578925.0
# Iteration = 3700
# Cost function =  7457617213856762.0
# Iteration = 3800
# Cost function =  7452311190128449.0
# Iteration = 3900
# Cost function =  7447009802230116.0
# Iteration = 4000
# Cost function =  7441713046001957.0
# Iteration = 4100
# Cost function =  7436420917288235.0
# Iteration = 4200
# Cost function =  7431133411937263.0
# Iteration = 4300
# Cost function =  7425850525801401.0
# Iteration = 4400
# Cost function =  7420572254737072.0
# Iteration = 4500
# Cost function =  7415298594604729.0
# Iteration = 4600
# Cost function =  7410029541268868.0
# Iteration = 4700
# Cost function =  7404765090598012.0
# Iteration = 4800
# Cost function =  7399505238464725.0
# Iteration = 4900
# Cost function =  7394249980745572.0
# Iteration = 5000
# Cost function =  7388999313321157.0
# Iteration = 5100
# Cost function =  7383753232076087.0
# Iteration = 5200
# Cost function =  7378511732898983.0
# Iteration = 5300
# Cost function =  7373274811682460.0
# Iteration = 5400
# Cost function =  7368042464323144.0
# Iteration = 5500
# Cost function =  7362814686721642.0
# Iteration = 5600
# Cost function =  7357591474782565.0
# Iteration = 5700
# Cost function =  7352372824414488.0
# Iteration = 5800
# Cost function =  7347158731529985.0
# Iteration = 5900
# Cost function =  7341949192045601.0
# Iteration = 6000
# Cost function =  7336744201881837.0
# Iteration = 6100
# Cost function =  7331543756963176.0
# Iteration = 6200
# Cost function =  7326347853218052.0
# Iteration = 6300
# Cost function =  7321156486578856.0
# Iteration = 6400
# Cost function =  7315969652981933.0
# Iteration = 6500
# Cost function =  7310787348367569.0
# Iteration = 6600
# Cost function =  7305609568679998.0
# Iteration = 6700
# Cost function =  7300436309867379.0
# Iteration = 6800
# Cost function =  7295267567881820.0
# Iteration = 6900
# Cost function =  7290103338679344.0
# Iteration = 7000
# Cost function =  7284943618219896.0
# Iteration = 7100
# Cost function =  7279788402467348.0
# Iteration = 7200
# Cost function =  7274637687389473.0
# Iteration = 7300
# Cost function =  7269491468957963.0
# Iteration = 7400
# Cost function =  7264349743148411.0
# Iteration = 7500
# Cost function =  7259212505940306.0
# Iteration = 7600
# Cost function =  7254079753317032.0
# Iteration = 7700
# Cost function =  7248951481265865.0
# Iteration = 7800
# Cost function =  7243827685777965.0
# Iteration = 7900
# Cost function =  7238708362848375.0
# Iteration = 8000
# Cost function =  7233593508476011.0
# Iteration = 8100
# Cost function =  7228483118663661.0
# Iteration = 8200
# Cost function =  7223377189417981.0
# Iteration = 8300
# Cost function =  7218275716749487.0
# Iteration = 8400
# Cost function =  7213178696672554.0
# Iteration = 8500
# Cost function =  7208086125205411.0
# Iteration = 8600
# Cost function =  7202997998370134.0
# Iteration = 8700
# Cost function =  7197914312192637.0
# Iteration = 8800
# Cost function =  7192835062702690.0
# Iteration = 8900
# Cost function =  7187760245933875.0
# Iteration = 9000
# Cost function =  7182689857923626.0
# Iteration = 9100
# Cost function =  7177623894713189.0
# Iteration = 9200
# Cost function =  7172562352347638.0
# Iteration = 9300
# Cost function =  7167505226875852.0
# Iteration = 9400
# Cost function =  7162452514350540.0
# Iteration = 9500
# Cost function =  7157404210828205.0
# Iteration = 9600
# Cost function =  7152360312369158.0
# Iteration = 9700
# Cost function =  7147320815037508.0
# Iteration = 9800
# Cost function =  7142285714901157.0
# Iteration = 9900
# Cost function =  7137255008031798.0
# Iteration = 10000
# Cost function =  7132228690504908.0
# Iteration = 10100
# Cost function =  7127206758399750.0
# Iteration = 10200
# Cost function =  7122189207799352.0
# Iteration = 10300
# Cost function =  7117176034790526.0
# Iteration = 10400
# Cost function =  7112167235463844.0
# Iteration = 10500
# Cost function =  7107162805913649.0
# Iteration = 10600
# Cost function =  7102162742238027.0
# Iteration = 10700
# Cost function =  7097167040538829.0
# Iteration = 10800
# Cost function =  7092175696921663.0
# Iteration = 10900
# Cost function =  7087188707495864.0
# Iteration = 11000
# Cost function =  7082206068374523.0
# Iteration = 11100
# Cost function =  7077227775674461.0
# Iteration = 11200
# Cost function =  7072253825516229.0
# Iteration = 11300
# Cost function =  7067284214024115.0
# Iteration = 11400
# Cost function =  7062318937326122.0
# Iteration = 11500
# Cost function =  7057357991553971.0
# Iteration = 11600
# Cost function =  7052401372843110.0
# Iteration = 11700
# Cost function =  7047449077332681.0
# Iteration = 11800
# Cost function =  7042501101165539.0
# Iteration = 11900
# Cost function =  7037557440488250.0
# Iteration = 12000
# Cost function =  7032618091451061.0
# Iteration = 12100
# Cost function =  7027683050207921.0
# Iteration = 12200
# Cost function =  7022752312916468.0
# Iteration = 12300
# Cost function =  7017825875738025.0
# Iteration = 12400
# Cost function =  7012903734837590.0
# Iteration = 12500
# Cost function =  7007985886383846.0
# Iteration = 12600
# Cost function =  7003072326549135.0
# Iteration = 12700
# Cost function =  6998163051509475.0
# Iteration = 12800
# Cost function =  6993258057444549.0
# Iteration = 12900
# Cost function =  6988357340537689.0
# Iteration = 13000
# Cost function =  6983460896975891.0
# Iteration = 13100
# Cost function =  6978568722949802.0
# Iteration = 13200
# Cost function =  6973680814653706.0
# Iteration = 13300
# Cost function =  6968797168285539.0
# Iteration = 13400
# Cost function =  6963917780046864.0
# Iteration = 13500
# Cost function =  6959042646142888.0
# Iteration = 13600
# Cost function =  6954171762782435.0
# Iteration = 13700
# Cost function =  6949305126177970.0
# Iteration = 13800
# Cost function =  6944442732545564.0
# Iteration = 13900
# Cost function =  6939584578104918.0
# Iteration = 14000
# Cost function =  6934730659079332.0
# Iteration = 14100
# Cost function =  6929880971695724.0
# Iteration = 14200
# Cost function =  6925035512184609.0
# Iteration = 14300
# Cost function =  6920194276780111.0
# Iteration = 14400
# Cost function =  6915357261719941.0
# Iteration = 14500
# Cost function =  6910524463245409.0
# Iteration = 14600
# Cost function =  6905695877601402.0
# Iteration = 14700
# Cost function =  6900871501036402.0
# Iteration = 14800
# Cost function =  6896051329802467.0
# Iteration = 14900
# Cost function =  6891235360155227.0
# Iteration = 15000
# Cost function =  6886423588353882.0
# Iteration = 15100
# Cost function =  6881616010661206.0
# Iteration = 15200
# Cost function =  6876812623343526.0
# Iteration = 15300
# Cost function =  6872013422670739.0
# Iteration = 15400
# Cost function =  6867218404916285.0
# Iteration = 15500
# Cost function =  6862427566357166.0
# Iteration = 15600
# Cost function =  6857640903273922.0
# Iteration = 15700
# Cost function =  6852858411950639.0
# Iteration = 15800
# Cost function =  6848080088674941.0
# Iteration = 15900
# Cost function =  6843305929737984.0
# Iteration = 16000
# Cost function =  6838535931434461.0
# Iteration = 16100
# Cost function =  6833770090062581.0
# Iteration = 16200
# Cost function =  6829008401924083.0
# Iteration = 16300
# Cost function =  6824250863324222.0
# Iteration = 16400
# Cost function =  6819497470571767.0
# Iteration = 16500
# Cost function =  6814748219978996.0
# Iteration = 16600
# Cost function =  6810003107861697.0
# Iteration = 16700
# Cost function =  6805262130539159.0
# Iteration = 16800
# Cost function =  6800525284334161.0
# Iteration = 16900
# Cost function =  6795792565572987.0
# Iteration = 17000
# Cost function =  6791063970585404.0
# Iteration = 17100
# Cost function =  6786339495704675.0
# Iteration = 17200
# Cost function =  6781619137267532.0
# Iteration = 17300
# Cost function =  6776902891614192.0
# Iteration = 17400
# Cost function =  6772190755088345.0
# Iteration = 17500
# Cost function =  6767482724037156.0
# Iteration = 17600
# Cost function =  6762778794811253.0
# Iteration = 17700
# Cost function =  6758078963764723.0
# Iteration = 17800
# Cost function =  6753383227255114.0
# Iteration = 17900
# Cost function =  6748691581643431.0
# Iteration = 18000
# Cost function =  6744004023294131.0
# Iteration = 18100
# Cost function =  6739320548575105.0
# Iteration = 18200
# Cost function =  6734641153857709.0
# Iteration = 18300
# Cost function =  6729965835516714.0
# Iteration = 18400
# Cost function =  6725294589930346.0
# Iteration = 18500
# Cost function =  6720627413480250.0
# Iteration = 18600
# Cost function =  6715964302551500.0
# Iteration = 18700
# Cost function =  6711305253532602.0
# Iteration = 18800
# Cost function =  6706650262815467.0
# Iteration = 18900
# Cost function =  6701999326795437.0
# Iteration = 19000
# Cost function =  6697352441871255.0
# Iteration = 19100
# Cost function =  6692709604445076.0
# Iteration = 19200
# Cost function =  6688070810922458.0
# Iteration = 19300
# Cost function =  6683436057712358.0
# Iteration = 19400
# Cost function =  6678805341227136.0
# Iteration = 19500
# Cost function =  6674178657882536.0
# Iteration = 19600
# Cost function =  6669556004097701.0
# Iteration = 19700
# Cost function =  6664937376295146.0
# Iteration = 19800
# Cost function =  6660322770900778.0
# Iteration = 19900
# Cost function =  6655712184343876.0
# Iteration = 20000
# Cost function =  6651105613057096.0
# Iteration = 20100
# Cost function =  6646503053476458.0
# Iteration = 20200
# Cost function =  6641904502041355.0
# Iteration = 20300
# Cost function =  6637309955194538.0
# Iteration = 20400
# Cost function =  6632719409382121.0
# Iteration = 20500
# Cost function =  6628132861053564.0
# Iteration = 20600
# Cost function =  6623550306661685.0
# Iteration = 20700
# Cost function =  6618971742662649.0
# Iteration = 20800
# Cost function =  6614397165515961.0
# Iteration = 20900
# Cost function =  6609826571684467.0
# Iteration = 21000
# Cost function =  6605259957634352.0
# Iteration = 21100
# Cost function =  6600697319835129.0
# Iteration = 21200
# Cost function =  6596138654759643.0
# Iteration = 21300
# Cost function =  6591583958884057.0
# Iteration = 21400
# Cost function =  6587033228687865.0
# Iteration = 21500
# Cost function =  6582486460653873.0
# Iteration = 21600
# Cost function =  6577943651268199.0
# Iteration = 21700
# Cost function =  6573404797020272.0
# Iteration = 21800
# Cost function =  6568869894402829.0
# Iteration = 21900
# Cost function =  6564338939911912.0
# Iteration = 22000
# Cost function =  6559811930046854.0
# Iteration = 22100
# Cost function =  6555288861310285.0
# Iteration = 22200
# Cost function =  6550769730208140.0
# Iteration = 22300
# Cost function =  6546254533249623.0
# Iteration = 22400
# Cost function =  6541743266947230.0
# Iteration = 22500
# Cost function =  6537235927816745.0
# Iteration = 22600
# Cost function =  6532732512377216.0
# Iteration = 22700
# Cost function =  6528233017150970.0
# Iteration = 22800
# Cost function =  6523737438663605.0
# Iteration = 22900
# Cost function =  6519245773443984.0
# Iteration = 23000
# Cost function =  6514758018024230.0
# Iteration = 23100
# Cost function =  6510274168939732.0
# Iteration = 23200
# Cost function =  6505794222729128.0
# Iteration = 23300
# Cost function =  6501318175934301.0
# Iteration = 23400
# Cost function =  6496846025100402.0
# Iteration = 23500
# Cost function =  6492377766775804.0
# Iteration = 23600
# Cost function =  6487913397512132.0
# Iteration = 23700
# Cost function =  6483452913864251.0
# Iteration = 23800
# Cost function =  6478996312390252.0
# Iteration = 23900
# Cost function =  6474543589651461.0
# Iteration = 24000
# Cost function =  6470094742212430.0
# Iteration = 24100
# Cost function =  6465649766640931.0
# Iteration = 24200
# Cost function =  6461208659507955.0
# Iteration = 24300
# Cost function =  6456771417387715.0
# Iteration = 24400
# Cost function =  6452338036857630.0
# Iteration = 24500
# Cost function =  6447908514498330.0
# Iteration = 24600
# Cost function =  6443482846893651.0
# Iteration = 24700
# Cost function =  6439061030630628.0
# Iteration = 24800
# Cost function =  6434643062299499.0
# Iteration = 24900
# Cost function =  6430228938493687.0
# Iteration = 25000
# Cost function =  6425818655809818.0
# Iteration = 25100
# Cost function =  6421412210847696.0
# Iteration = 25200
# Cost function =  6417009600210316.0
# Iteration = 25300
# Cost function =  6412610820503848.0
# Iteration = 25400
# Cost function =  6408215868337644.0
# Iteration = 25500
# Cost function =  6403824740324223.0
# Iteration = 25600
# Cost function =  6399437433079283.0
# Iteration = 25700
# Cost function =  6395053943221679.0
# Iteration = 25800
# Cost function =  6390674267373438.0
# Iteration = 25900
# Cost function =  6386298402159741.0
# Iteration = 26000
# Cost function =  6381926344208925.0
# Iteration = 26100
# Cost function =  6377558090152482.0
# Iteration = 26200
# Cost function =  6373193636625053.0
# Iteration = 26300
# Cost function =  6368832980264425.0
# Iteration = 26400
# Cost function =  6364476117711526.0
# Iteration = 26500
# Cost function =  6360123045610422.0
# Iteration = 26600
# Cost function =  6355773760608324.0
# Iteration = 26700
# Cost function =  6351428259355562.0
# Iteration = 26800
# Cost function =  6347086538505597.0
# Iteration = 26900
# Cost function =  6342748594715027.0
# Iteration = 27000
# Cost function =  6338414424643557.0
# Iteration = 27100
# Cost function =  6334084024954018.0
# Iteration = 27200
# Cost function =  6329757392312352.0
# Iteration = 27300
# Cost function =  6325434523387623.0
# Iteration = 27400
# Cost function =  6321115414851987.0
# Iteration = 27500
# Cost function =  6316800063380717.0
# Iteration = 27600
# Cost function =  6312488465652192.0
# Iteration = 27700
# Cost function =  6308180618347870.0
# Iteration = 27800
# Cost function =  6303876518152318.0
# Iteration = 27900
# Cost function =  6299576161753194.0
# Iteration = 28000
# Cost function =  6295279545841242.0
# Iteration = 28100
# Cost function =  6290986667110287.0
# Iteration = 28200
# Cost function =  6286697522257238.0
# Iteration = 28300
# Cost function =  6282412107982087.0
# Iteration = 28400
# Cost function =  6278130420987890.0
# Iteration = 28500
# Cost function =  6273852457980788.0
# Iteration = 28600
# Cost function =  6269578215669977.0
# Iteration = 28700
# Cost function =  6265307690767724.0
# Iteration = 28800
# Cost function =  6261040879989354.0
# Iteration = 28900
# Cost function =  6256777780053257.0
# Iteration = 29000
# Cost function =  6252518387680870.0
# Iteration = 29100
# Cost function =  6248262699596686.0
# Iteration = 29200
# Cost function =  6244010712528242.0
# Iteration = 29300
# Cost function =  6239762423206126.0
# Iteration = 29400
# Cost function =  6235517828363962.0
# Iteration = 29500
# Cost function =  6231276924738413.0
# Iteration = 29600
# Cost function =  6227039709069179.0
# Iteration = 29700
# Cost function =  6222806178098990.0
# Iteration = 29800
# Cost function =  6218576328573610.0
# Iteration = 29900
# Cost function =  6214350157241817.0
# Iteration = 30000
# Cost function =  6210127660855422.0
# Iteration = 30100
# Cost function =  6205908836169243.0
# Iteration = 30200
# Cost function =  6201693679941128.0
# Iteration = 30300
# Cost function =  6197482188931923.0
# Iteration = 30400
# Cost function =  6193274359905493.0
# Iteration = 30500
# Cost function =  6189070189628702.0
# Iteration = 30600
# Cost function =  6184869674871422.0
# Iteration = 30700
# Cost function =  6180672812406517.0
# Iteration = 30800
# Cost function =  6176479599009856.0
# Iteration = 30900
# Cost function =  6172290031460291.0
# Iteration = 31000
# Cost function =  6168104106539671.0
# Iteration = 31100
# Cost function =  6163921821032835.0
# Iteration = 31200
# Cost function =  6159743171727585.0
# Iteration = 31300
# Cost function =  6155568155414725.0
# Iteration = 31400
# Cost function =  6151396768888032.0
# Iteration = 31500
# Cost function =  6147229008944244.0
# Iteration = 31600
# Cost function =  6143064872383078.0
# Iteration = 31700
# Cost function =  6138904356007220.0
# Iteration = 31800
# Cost function =  6134747456622319.0
# Iteration = 31900
# Cost function =  6130594171036977.0
# Iteration = 32000
# Cost function =  6126444496062767.0
# Iteration = 32100
# Cost function =  6122298428514206.0
# Iteration = 32200
# Cost function =  6118155965208765.0
# Iteration = 32300
# Cost function =  6114017102966863.0
# Iteration = 32400
# Cost function =  6109881838611865.0
# Iteration = 32500
# Cost function =  6105750168970080.0
# Iteration = 32600
# Cost function =  6101622090870749.0
# Iteration = 32700
# Cost function =  6097497601146058.0
# Iteration = 32800
# Cost function =  6093376696631113.0
# Iteration = 32900
# Cost function =  6089259374163965.0
# Iteration = 33000
# Cost function =  6085145630585579.0
# Iteration = 33100
# Cost function =  6081035462739846.0
# Iteration = 33200
# Cost function =  6076928867473579.0
# Iteration = 33300
# Cost function =  6072825841636506.0
# Iteration = 33400
# Cost function =  6068726382081270.0
# Iteration = 33500
# Cost function =  6064630485663423.0
# Iteration = 33600
# Cost function =  6060538149241422.0
# Iteration = 33700
# Cost function =  6056449369676639.0
# Iteration = 33800
# Cost function =  6052364143833337.0
# Iteration = 33900
# Cost function =  6048282468578679.0
# Iteration = 34000
# Cost function =  6044204340782727.0
# Iteration = 34100
# Cost function =  6040129757318436.0
# Iteration = 34200
# Cost function =  6036058715061641.0
# Iteration = 34300
# Cost function =  6031991210891074.0
# Iteration = 34400
# Cost function =  6027927241688343.0
# Iteration = 34500
# Cost function =  6023866804337939.0
# Iteration = 34600
# Cost function =  6019809895727226.0
# Iteration = 34700
# Cost function =  6015756512746445.0
# Iteration = 34800
# Cost function =  6011706652288711.0
# Iteration = 34900
# Cost function =  6007660311250001.0
# Iteration = 35000
# Cost function =  6003617486529160.0
# Iteration = 35100
# Cost function =  5999578175027890.0
# Iteration = 35200
# Cost function =  5995542373650754.0
# Iteration = 35300
# Cost function =  5991510079305177.0
# Iteration = 35400
# Cost function =  5987481288901427.0
# Iteration = 35500
# Cost function =  5983455999352628.0
# Iteration = 35600
# Cost function =  5979434207574747.0
# Iteration = 35700
# Cost function =  5975415910486596.0
# Iteration = 35800
# Cost function =  5971401105009832.0
# Iteration = 35900
# Cost function =  5967389788068935.0
# Iteration = 36000
# Cost function =  5963381956591236.0
# Iteration = 36100
# Cost function =  5959377607506891.0
# Iteration = 36200
# Cost function =  5955376737748882.0
# Iteration = 36300
# Cost function =  5951379344253022.0
# Iteration = 36400
# Cost function =  5947385423957944.0
# Iteration = 36500
# Cost function =  5943394973805098.0
# Iteration = 36600
# Cost function =  5939407990738755.0
# Iteration = 36700
# Cost function =  5935424471705997.0
# Iteration = 36800
# Cost function =  5931444413656721.0
# Iteration = 36900
# Cost function =  5927467813543623.0
# Iteration = 37000
# Cost function =  5923494668322212.0
# Iteration = 37100
# Cost function =  5919524974950798.0
# Iteration = 37200
# Cost function =  5915558730390485.0
# Iteration = 37300
# Cost function =  5911595931605182.0
# Iteration = 37400
# Cost function =  5907636575561581.0
# Iteration = 37500
# Cost function =  5903680659229168.0
# Iteration = 37600
# Cost function =  5899728179580224.0
# Iteration = 37700
# Cost function =  5895779133589801.0
# Iteration = 37800
# Cost function =  5891833518235742.0
# Iteration = 37900
# Cost function =  5887891330498663.0
# Iteration = 38000
# Cost function =  5883952567361957.0
# Iteration = 38100
# Cost function =  5880017225811794.0
# Iteration = 38200
# Cost function =  5876085302837108.0
# Iteration = 38300
# Cost function =  5872156795429605.0
# Iteration = 38400
# Cost function =  5868231700583750.0
# Iteration = 38500
# Cost function =  5864310015296771.0
# Iteration = 38600
# Cost function =  5860391736568659.0
# Iteration = 38700
# Cost function =  5856476861402151.0
# Iteration = 38800
# Cost function =  5852565386802742.0
# Iteration = 38900
# Cost function =  5848657309778682.0
# Iteration = 39000
# Cost function =  5844752627340957.0
# Iteration = 39100
# Cost function =  5840851336503300.0
# Iteration = 39200
# Cost function =  5836953434282191.0
# Iteration = 39300
# Cost function =  5833058917696842.0
# Iteration = 39400
# Cost function =  5829167783769207.0
# Iteration = 39500
# Cost function =  5825280029523960.0
# Iteration = 39600
# Cost function =  5821395651988519.0
# Iteration = 39700
# Cost function =  5817514648193020.0
# Iteration = 39800
# Cost function =  5813637015170323.0
# Iteration = 39900
# Cost function =  5809762749956014.0
# Iteration = 40000
# Cost function =  5805891849588393.0
# Iteration = 40100
# Cost function =  5802024311108476.0
# Iteration = 40200
# Cost function =  5798160131559994.0
# Iteration = 40300
# Cost function =  5794299307989387.0
# Iteration = 40400
# Cost function =  5790441837445800.0
# Iteration = 40500
# Cost function =  5786587716981085.0
# Iteration = 40600
# Cost function =  5782736943649792.0
# Iteration = 40700
# Cost function =  5778889514509175.0
# Iteration = 40800
# Cost function =  5775045426619179.0
# Iteration = 40900
# Cost function =  5771204677042440.0
# Iteration = 41000
# Cost function =  5767367262844293.0
# Iteration = 41100
# Cost function =  5763533181092750.0
# Iteration = 41200
# Cost function =  5759702428858514.0
# Iteration = 41300
# Cost function =  5755875003214970.0
# Iteration = 41400
# Cost function =  5752050901238177.0
# Iteration = 41500
# Cost function =  5748230120006879.0
# Iteration = 41600
# Cost function =  5744412656602485.0
# Iteration = 41700
# Cost function =  5740598508109076.0
# Iteration = 41800
# Cost function =  5736787671613408.0
# Iteration = 41900
# Cost function =  5732980144204896.0
# Iteration = 42000
# Cost function =  5729175922975619.0
# Iteration = 42100
# Cost function =  5725375005020312.0
# Iteration = 42200
# Cost function =  5721577387436372.0
# Iteration = 42300
# Cost function =  5717783067323854.0
# Iteration = 42400
# Cost function =  5713992041785456.0
# Iteration = 42500
# Cost function =  5710204307926528.0
# Iteration = 42600
# Cost function =  5706419862855064.0
# Iteration = 42700
# Cost function =  5702638703681707.0
# Iteration = 42800
# Cost function =  5698860827519741.0
# Iteration = 42900
# Cost function =  5695086231485070.0
# Iteration = 43000
# Cost function =  5691314912696263.0
# Iteration = 43100
# Cost function =  5687546868274496.0
# Iteration = 43200
# Cost function =  5683782095343590.0
# Iteration = 43300
# Cost function =  5680020591029987.0
# Iteration = 43400
# Cost function =  5676262352462752.0
# Iteration = 43500
# Cost function =  5672507376773574.0
# Iteration = 43600
# Cost function =  5668755661096761.0
# Iteration = 43700
# Cost function =  5665007202569237.0
# Iteration = 43800
# Cost function =  5661261998330542.0
# Iteration = 43900
# Cost function =  5657520045522821.0
# Iteration = 44000
# Cost function =  5653781341290830.0
# Iteration = 44100
# Cost function =  5650045882781935.0
# Iteration = 44200
# Cost function =  5646313667146099.0
# Iteration = 44300
# Cost function =  5642584691535888.0
# Iteration = 44400
# Cost function =  5638858953106463.0
# Iteration = 44500
# Cost function =  5635136449015578.0
# Iteration = 44600
# Cost function =  5631417176423591.0
# Iteration = 44700
# Cost function =  5627701132493439.0
# Iteration = 44800
# Cost function =  5623988314390646.0
# Iteration = 44900
# Cost function =  5620278719283327.0
# Iteration = 45000
# Cost function =  5616572344342168.0
# Iteration = 45100
# Cost function =  5612869186740449.0
# Iteration = 45200
# Cost function =  5609169243654011.0
# Iteration = 45300
# Cost function =  5605472512261279.0
# Iteration = 45400
# Cost function =  5601778989743241.0
# Iteration = 45500
# Cost function =  5598088673283459.0
# Iteration = 45600
# Cost function =  5594401560068065.0
# Iteration = 45700
# Cost function =  5590717647285749.0
# Iteration = 45800
# Cost function =  5587036932127752.0
# Iteration = 45900
# Cost function =  5583359411787892.0
# Iteration = 46000
# Cost function =  5579685083462532.0
# Iteration = 46100
# Cost function =  5576013944350588.0
# Iteration = 46200
# Cost function =  5572345991653526.0
# Iteration = 46300
# Cost function =  5568681222575362.0
# Iteration = 46400
# Cost function =  5565019634322654.0
# Iteration = 46500
# Cost function =  5561361224104503.0
# Iteration = 46600
# Cost function =  5557705989132560.0
# Iteration = 46700
# Cost function =  5554053926620993.0
# Iteration = 46800
# Cost function =  5550405033786524.0
# Iteration = 46900
# Cost function =  5546759307848389.0
# Iteration = 47000
# Cost function =  5543116746028376.0
# Iteration = 47100
# Cost function =  5539477345550779.0
# Iteration = 47200
# Cost function =  5535841103642424.0
# Iteration = 47300
# Cost function =  5532208017532668.0
# Iteration = 47400
# Cost function =  5528578084453367.0
# Iteration = 47500
# Cost function =  5524951301638912.0
# Iteration = 47600
# Cost function =  5521327666326202.0
# Iteration = 47700
# Cost function =  5517707175754648.0
# Iteration = 47800
# Cost function =  5514089827166165.0
# Iteration = 47900
# Cost function =  5510475617805180.0
# Iteration = 48000
# Cost function =  5506864544918622.0
# Iteration = 48100
# Cost function =  5503256605755928.0
# Iteration = 48200
# Cost function =  5499651797569023.0
# Iteration = 48300
# Cost function =  5496050117612332.0
# Iteration = 48400
# Cost function =  5492451563142776.0
# Iteration = 48500
# Cost function =  5488856131419768.0
# Iteration = 48600
# Cost function =  5485263819705207.0
# Iteration = 48700
# Cost function =  5481674625263481.0
# Iteration = 48800
# Cost function =  5478088545361457.0
# Iteration = 48900
# Cost function =  5474505577268490.0
# Iteration = 49000
# Cost function =  5470925718256407.0
# Iteration = 49100
# Cost function =  5467348965599516.0
# Iteration = 49200
# Cost function =  5463775316574599.0
# Iteration = 49300
# Cost function =  5460204768460905.0
# Iteration = 49400
# Cost function =  5456637318540153.0
# Iteration = 49500
# Cost function =  5453072964096532.0
# Iteration = 49600
# Cost function =  5449511702416689.0
# Iteration = 49700
# Cost function =  5445953530789735.0
# Iteration = 49800
# Cost function =  5442398446507246.0
# Iteration = 49900
# Cost function =  5438846446863243.0
# Iteration = 50000
# Cost function =  5435297529154208.0
# Iteration = 50100
# Cost function =  5431751690679072.0
# Iteration = 50200
# Cost function =  5428208928739214.0
# Iteration = 50300
# Cost function =  5424669240638464.0
# Iteration = 50400
# Cost function =  5421132623683091.0
# Iteration = 50500
# Cost function =  5417599075181810.0
# Iteration = 50600
# Cost function =  5414068592445771.0
# Iteration = 50700
# Cost function =  5410541172788563.0
# Iteration = 50800
# Cost function =  5407016813526205.0
# Iteration = 50900
# Cost function =  5403495511977155.0
# Iteration = 51000
# Cost function =  5399977265462291.0
# Iteration = 51100
# Cost function =  5396462071304927.0
# Iteration = 51200
# Cost function =  5392949926830799.0
# Iteration = 51300
# Cost function =  5389440829368058.0
# Iteration = 51400
# Cost function =  5385934776247287.0
# Iteration = 51500
# Cost function =  5382431764801473.0
# Iteration = 51600
# Cost function =  5378931792366024.0
# Iteration = 51700
# Cost function =  5375434856278762.0
# Iteration = 51800
# Cost function =  5371940953879916.0
# Iteration = 51900
# Cost function =  5368450082512125.0
# Iteration = 52000
# Cost function =  5364962239520428.0
# Iteration = 52100
# Cost function =  5361477422252271.0
# Iteration = 52200
# Cost function =  5357995628057501.0
# Iteration = 52300
# Cost function =  5354516854288359.0
# Iteration = 52400
# Cost function =  5351041098299480.0
# Iteration = 52500
# Cost function =  5347568357447903.0
# Iteration = 52600
# Cost function =  5344098629093039.0
# Iteration = 52700
# Cost function =  5340631910596712.0
# Iteration = 52800
# Cost function =  5337168199323103.0
# Iteration = 52900
# Cost function =  5333707492638804.0
# Iteration = 53000
# Cost function =  5330249787912768.0
# Iteration = 53100
# Cost function =  5326795082516333.0
# Iteration = 53200
# Cost function =  5323343373823219.0
# Iteration = 53300
# Cost function =  5319894659209515.0
# Iteration = 53400
# Cost function =  5316448936053677.0
# Iteration = 53500
# Cost function =  5313006201736539.0
# Iteration = 53600
# Cost function =  5309566453641296.0
# Iteration = 53700
# Cost function =  5306129689153510.0
# Iteration = 53800
# Cost function =  5302695905661104.0
# Iteration = 53900
# Cost function =  5299265100554360.0
# Iteration = 54000
# Cost function =  5295837271225923.0
# Iteration = 54100
# Cost function =  5292412415070782.0
# Iteration = 54200
# Cost function =  5288990529486296.0
# Iteration = 54300
# Cost function =  5285571611872152.0
# Iteration = 54400
# Cost function =  5282155659630402.0
# Iteration = 54500
# Cost function =  5278742670165443.0
# Iteration = 54600
# Cost function =  5275332640884004.0
# Iteration = 54700
# Cost function =  5271925569195161.0
# Iteration = 54800
# Cost function =  5268521452510334.0
# Iteration = 54900
# Cost function =  5265120288243276.0
# Iteration = 55000
# Cost function =  5261722073810071.0
# Iteration = 55100
# Cost function =  5258326806629133.0
# Iteration = 55200
# Cost function =  5254934484121217.0
# Iteration = 55300
# Cost function =  5251545103709392.0
# Iteration = 55400
# Cost function =  5248158662819058.0
# Iteration = 55500
# Cost function =  5244775158877940.0
# Iteration = 55600
# Cost function =  5241394589316077.0
# Iteration = 55700
# Cost function =  5238016951565825.0
# Iteration = 55800
# Cost function =  5234642243061870.0
# Iteration = 55900
# Cost function =  5231270461241192.0
# Iteration = 56000
# Cost function =  5227901603543093.0
# Iteration = 56100
# Cost function =  5224535667409182.0
# Iteration = 56200
# Cost function =  5221172650283378.0
# Iteration = 56300
# Cost function =  5217812549611892.0
# Iteration = 56400
# Cost function =  5214455362843251.0
# Iteration = 56500
# Cost function =  5211101087428271.0
# Iteration = 56600
# Cost function =  5207749720820073.0
# Iteration = 56700
# Cost function =  5204401260474069.0
# Iteration = 56800
# Cost function =  5201055703847966.0
# Iteration = 56900
# Cost function =  5197713048401764.0
# Iteration = 57000
# Cost function =  5194373291597737.0
# Iteration = 57100
# Cost function =  5191036430900463.0
# Iteration = 57200
# Cost function =  5187702463776796.0
# Iteration = 57300
# Cost function =  5184371387695867.0
# Iteration = 57400
# Cost function =  5181043200129097.0
# Iteration = 57500
# Cost function =  5177717898550175.0
# Iteration = 57600
# Cost function =  5174395480435063.0
# Iteration = 57700
# Cost function =  5171075943262009.0
# Iteration = 57800
# Cost function =  5167759284511517.0
# Iteration = 57900
# Cost function =  5164445501666366.0
# Iteration = 58000
# Cost function =  5161134592211598.0
# Iteration = 58100
# Cost function =  5157826553634520.0
# Iteration = 58200
# Cost function =  5154521383424701.0
# Iteration = 58300
# Cost function =  5151219079073967.0
# Iteration = 58400
# Cost function =  5147919638076402.0
# Iteration = 58500
# Cost function =  5144623057928345.0
# Iteration = 58600
# Cost function =  5141329336128383.0
# Iteration = 58700
# Cost function =  5138038470177362.0
# Iteration = 58800
# Cost function =  5134750457578371.0
# Iteration = 58900
# Cost function =  5131465295836742.0
# Iteration = 59000
# Cost function =  5128182982460054.0
# Iteration = 59100
# Cost function =  5124903514958132.0
# Iteration = 59200
# Cost function =  5121626890843027.0
# Iteration = 59300
# Cost function =  5118353107629037.0
# Iteration = 59400
# Cost function =  5115082162832697.0
# Iteration = 59500
# Cost function =  5111814053972763.0
# Iteration = 59600
# Cost function =  5108548778570237.0
# Iteration = 59700
# Cost function =  5105286334148331.0
# Iteration = 59800
# Cost function =  5102026718232505.0
# Iteration = 59900
# Cost function =  5098769928350420.0
# Iteration = 60000
# Cost function =  5095515962031969.0
# Iteration = 60100
# Cost function =  5092264816809272.0
# Iteration = 60200
# Cost function =  5089016490216655.0
# Iteration = 60300
# Cost function =  5085770979790663.0
# Iteration = 60400
# Cost function =  5082528283070053.0
# Iteration = 60500
# Cost function =  5079288397595795.0
# Iteration = 60600
# Cost function =  5076051320911068.0
# Iteration = 60700
# Cost function =  5072817050561250.0
# Iteration = 60800
# Cost function =  5069585584093933.0
# Iteration = 60900
# Cost function =  5066356919058908.0
# Iteration = 61000
# Cost function =  5063131053008161.0
# Iteration = 61100
# Cost function =  5059907983495882.0
# Iteration = 61200
# Cost function =  5056687708078455.0
# Iteration = 61300
# Cost function =  5053470224314458.0
# Iteration = 61400
# Cost function =  5050255529764654.0
# Iteration = 61500
# Cost function =  5047043621992005.0
# Iteration = 61600
# Cost function =  5043834498561656.0
# Iteration = 61700
# Cost function =  5040628157040936.0
# Iteration = 61800
# Cost function =  5037424594999357.0
# Iteration = 61900
# Cost function =  5034223810008615.0
# Iteration = 62000
# Cost function =  5031025799642574.0
# Iteration = 62100
# Cost function =  5027830561477288.0
# Iteration = 62200
# Cost function =  5024638093090977.0
# Iteration = 62300
# Cost function =  5021448392064039.0
# Iteration = 62400
# Cost function =  5018261455979033.0
# Iteration = 62500
# Cost function =  5015077282420697.0
# Iteration = 62600
# Cost function =  5011895868975928.0
# Iteration = 62700
# Cost function =  5008717213233786.0
# Iteration = 62800
# Cost function =  5005541312785495.0
# Iteration = 62900
# Cost function =  5002368165224440.0
# Iteration = 63000
# Cost function =  4999197768146160.0
# Iteration = 63100
# Cost function =  4996030119148354.0
# Iteration = 63200
# Cost function =  4992865215830866.0
# Iteration = 63300
# Cost function =  4989703055795704.0
# Iteration = 63400
# Cost function =  4986543636647008.0
# Iteration = 63500
# Cost function =  4983386955991083.0
# Iteration = 63600
# Cost function =  4980233011436362.0
# Iteration = 63700
# Cost function =  4977081800593439.0
# Iteration = 63800
# Cost function =  4973933321075028.0
# Iteration = 63900
# Cost function =  4970787570495996.0
# Iteration = 64000
# Cost function =  4967644546473344.0
# Iteration = 64100
# Cost function =  4964504246626204.0
# Iteration = 64200
# Cost function =  4961366668575843.0
# Iteration = 64300
# Cost function =  4958231809945658.0
# Iteration = 64400
# Cost function =  4955099668361175.0
# Iteration = 64500
# Cost function =  4951970241450042.0
# Iteration = 64600
# Cost function =  4948843526842037.0
# Iteration = 64700
# Cost function =  4945719522169062.0
# Iteration = 64800
# Cost function =  4942598225065126.0
# Iteration = 64900
# Cost function =  4939479633166364.0
# Iteration = 65000
# Cost function =  4936363744111031.0
# Iteration = 65100
# Cost function =  4933250555539489.0
# Iteration = 65200
# Cost function =  4930140065094220.0
# Iteration = 65300
# Cost function =  4927032270419809.0
# Iteration = 65400
# Cost function =  4923927169162942.0
# Iteration = 65500
# Cost function =  4920824758972430.0
# Iteration = 65600
# Cost function =  4917725037499172.0
# Iteration = 65700
# Cost function =  4914628002396169.0
# Iteration = 65800
# Cost function =  4911533651318527.0
# Iteration = 65900
# Cost function =  4908441981923446.0
# Iteration = 66000
# Cost function =  4905352991870233.0
# Iteration = 66100
# Cost function =  4902266678820267.0
# Iteration = 66200
# Cost function =  4899183040437037.0
# Iteration = 66300
# Cost function =  4896102074386110.0
# Iteration = 66400
# Cost function =  4893023778335151.0
# Iteration = 66500
# Cost function =  4889948149953905.0
# Iteration = 66600
# Cost function =  4886875186914195.0
# Iteration = 66700
# Cost function =  4883804886889932.0
# Iteration = 66800
# Cost function =  4880737247557100.0
# Iteration = 66900
# Cost function =  4877672266593773.0
# Iteration = 67000
# Cost function =  4874609941680085.0
# Iteration = 67100
# Cost function =  4871550270498256.0
# Iteration = 67200
# Cost function =  4868493250732565.0
# Iteration = 67300
# Cost function =  4865438880069374.0
# Iteration = 67400
# Cost function =  4862387156197105.0
# Iteration = 67500
# Cost function =  4859338076806239.0
# Iteration = 67600
# Cost function =  4856291639589335.0
# Iteration = 67700
# Cost function =  4853247842240996.0
# Iteration = 67800
# Cost function =  4850206682457901.0
# Iteration = 67900
# Cost function =  4847168157938778.0
# Iteration = 68000
# Cost function =  4844132266384410.0
# Iteration = 68100
# Cost function =  4841099005497636.0
# Iteration = 68200
# Cost function =  4838068372983342.0
# Iteration = 68300
# Cost function =  4835040366548473.0
# Iteration = 68400
# Cost function =  4832014983902015.0
# Iteration = 68500
# Cost function =  4828992222754998.0
# Iteration = 68600
# Cost function =  4825972080820492.0
# Iteration = 68700
# Cost function =  4822954555813628.0
# Iteration = 68800
# Cost function =  4819939645451545.0
# Iteration = 68900
# Cost function =  4816927347453446.0
# Iteration = 69000
# Cost function =  4813917659540564.0
# Iteration = 69100
# Cost function =  4810910579436160.0
# Iteration = 69200
# Cost function =  4807906104865528.0
# Iteration = 69300
# Cost function =  4804904233555996.0
# Iteration = 69400
# Cost function =  4801904963236916.0
# Iteration = 69500
# Cost function =  4798908291639668.0
# Iteration = 69600
# Cost function =  4795914216497655.0
# Iteration = 69700
# Cost function =  4792922735546298.0
# Iteration = 69800
# Cost function =  4789933846523052.0
# Iteration = 69900
# Cost function =  4786947547167375.0
# Iteration = 70000
# Cost function =  4783963835220747.0
# Iteration = 70100
# Cost function =  4780982708426666.0
# Iteration = 70200
# Cost function =  4778004164530632.0
# Iteration = 70300
# Cost function =  4775028201280171.0
# Iteration = 70400
# Cost function =  4772054816424799.0
# Iteration = 70500
# Cost function =  4769084007716054.0
# Iteration = 70600
# Cost function =  4766115772907470.0
# Iteration = 70700
# Cost function =  4763150109754594.0
# Iteration = 70800
# Cost function =  4760187016014961.0
# Iteration = 70900
# Cost function =  4757226489448111.0
# Iteration = 71000
# Cost function =  4754268527815579.0
# Iteration = 71100
# Cost function =  4751313128880900.0
# Iteration = 71200
# Cost function =  4748360290409594.0
# Iteration = 71300
# Cost function =  4745410010169189.0
# Iteration = 71400
# Cost function =  4742462285929177.0
# Iteration = 71500
# Cost function =  4739517115461057.0
# Iteration = 71600
# Cost function =  4736574496538309.0
# Iteration = 71700
# Cost function =  4733634426936393.0
# Iteration = 71800
# Cost function =  4730696904432754.0
# Iteration = 71900
# Cost function =  4727761926806818.0
# Iteration = 72000
# Cost function =  4724829491839983.0
# Iteration = 72100
# Cost function =  4721899597315634.0
# Iteration = 72200
# Cost function =  4718972241019118.0
# Iteration = 72300
# Cost function =  4716047420737764.0
# Iteration = 72400
# Cost function =  4713125134260860.0
# Iteration = 72500
# Cost function =  4710205379379679.0
# Iteration = 72600
# Cost function =  4707288153887445.0
# Iteration = 72700
# Cost function =  4704373455579355.0
# Iteration = 72800
# Cost function =  4701461282252571.0
# Iteration = 72900
# Cost function =  4698551631706210.0
# Iteration = 73000
# Cost function =  4695644501741350.0
# Iteration = 73100
# Cost function =  4692739890161029.0
# Iteration = 73200
# Cost function =  4689837794770240.0
# Iteration = 73300
# Cost function =  4686938213375920.0
# Iteration = 73400
# Cost function =  4684041143786978.0
# Iteration = 73500
# Cost function =  4681146583814257.0
# Iteration = 73600
# Cost function =  4678254531270546.0
# Iteration = 73700
# Cost function =  4675364983970589.0
# Iteration = 73800
# Cost function =  4672477939731075.0
# Iteration = 73900
# Cost function =  4669593396370629.0
# Iteration = 74000
# Cost function =  4666711351709820.0
# Iteration = 74100
# Cost function =  4663831803571159.0
# Iteration = 74200
# Cost function =  4660954749779088.0
# Iteration = 74300
# Cost function =  4658080188159985.0
# Iteration = 74400
# Cost function =  4655208116542167.0
# Iteration = 74500
# Cost function =  4652338532755874.0
# Iteration = 74600
# Cost function =  4649471434633284.0
# Iteration = 74700
# Cost function =  4646606820008491.0
# Iteration = 74800
# Cost function =  4643744686717535.0
# Iteration = 74900
# Cost function =  4640885032598360.0
# Iteration = 75000
# Cost function =  4638027855490837.0
# Iteration = 75100
# Cost function =  4635173153236769.0
# Iteration = 75200
# Cost function =  4632320923679862.0
# Iteration = 75300
# Cost function =  4629471164665747.0
# Iteration = 75400
# Cost function =  4626623874041972.0
# Iteration = 75500
# Cost function =  4623779049657995.0
# Iteration = 75600
# Cost function =  4620936689365185.0
# Iteration = 75700
# Cost function =  4618096791016819.0
# Iteration = 75800
# Cost function =  4615259352468086.0
# Iteration = 75900
# Cost function =  4612424371576077.0
# Iteration = 76000
# Cost function =  4609591846199790.0
# Iteration = 76100
# Cost function =  4606761774200125.0
# Iteration = 76200
# Cost function =  4603934153439879.0
# Iteration = 76300
# Cost function =  4601108981783754.0
# Iteration = 76400
# Cost function =  4598286257098345.0
# Iteration = 76500
# Cost function =  4595465977252136.0
# Iteration = 76600
# Cost function =  4592648140115520.0
# Iteration = 76700
# Cost function =  4589832743560769.0
# Iteration = 76800
# Cost function =  4587019785462046.0
# Iteration = 76900
# Cost function =  4584209263695401.0
# Iteration = 77000
# Cost function =  4581401176138786.0
# Iteration = 77100
# Cost function =  4578595520672009.0
# Iteration = 77200
# Cost function =  4575792295176784.0
# Iteration = 77300
# Cost function =  4572991497536701.0
# Iteration = 77400
# Cost function =  4570193125637220.0
# Iteration = 77500
# Cost function =  4567397177365692.0
# Iteration = 77600
# Cost function =  4564603650611325.0
# Iteration = 77700
# Cost function =  4561812543265223.0
# Iteration = 77800
# Cost function =  4559023853220342.0
# Iteration = 77900
# Cost function =  4556237578371518.0
# Iteration = 78000
# Cost function =  4553453716615456.0
# Iteration = 78100
# Cost function =  4550672265850729.0
# Iteration = 78200
# Cost function =  4547893223977766.0
# Iteration = 78300
# Cost function =  4545116588898871.0
# Iteration = 78400
# Cost function =  4542342358518197.0
# Iteration = 78500
# Cost function =  4539570530741765.0
# Iteration = 78600
# Cost function =  4536801103477457.0
# Iteration = 78700
# Cost function =  4534034074634996.0
# Iteration = 78800
# Cost function =  4531269442125978.0
# Iteration = 78900
# Cost function =  4528507203863840.0
# Iteration = 79000
# Cost function =  4525747357763871.0
# Iteration = 79100
# Cost function =  4522989901743211.0
# Iteration = 79200
# Cost function =  4520234833720849.0
# Iteration = 79300
# Cost function =  4517482151617617.0
# Iteration = 79400
# Cost function =  4514731853356189.0
# Iteration = 79500
# Cost function =  4511983936861091.0
# Iteration = 79600
# Cost function =  4509238400058673.0
# Iteration = 79700
# Cost function =  4506495240877144.0
# Iteration = 79800
# Cost function =  4503754457246532.0
# Iteration = 79900
# Cost function =  4501016047098706.5
# Iteration = 80000
# Cost function =  4498280008367374.0
# Iteration = 80100
# Cost function =  4495546338988069.0
# Iteration = 80200
# Cost function =  4492815036898159.5
# Iteration = 80300
# Cost function =  4490086100036835.5
# Iteration = 80400
# Cost function =  4487359526345120.0
# Iteration = 80500
# Cost function =  4484635313765857.5
# Iteration = 80600
# Cost function =  4481913460243720.5
# Iteration = 80700
# Cost function =  4479193963725195.5
# Iteration = 80800
# Cost function =  4476476822158591.0
# Iteration = 80900
# Cost function =  4473762033494037.5
# Iteration = 81000
# Cost function =  4471049595683478.0
# Iteration = 81100
# Cost function =  4468339506680675.5
# Iteration = 81200
# Cost function =  4465631764441197.5
# Iteration = 81300
# Cost function =  4462926366922427.5
# Iteration = 81400
# Cost function =  4460223312083565.0
# Iteration = 81500
# Cost function =  4457522597885601.5
# Iteration = 81600
# Cost function =  4454824222291347.0
# Iteration = 81700
# Cost function =  4452128183265409.5
# Iteration = 81800
# Cost function =  4449434478774209.5
# Iteration = 81900
# Cost function =  4446743106785957.0
# Iteration = 82000
# Cost function =  4444054065270667.5
# Iteration = 82100
# Cost function =  4441367352200147.0
# Iteration = 82200
# Cost function =  4438682965548014.0
# Iteration = 82300
# Cost function =  4436000903289668.0
# Iteration = 82400
# Cost function =  4433321163402300.0
# Iteration = 82500
# Cost function =  4430643743864897.5
# Iteration = 82600
# Cost function =  4427968642658239.0
# Iteration = 82700
# Cost function =  4425295857764882.5
# Iteration = 82800
# Cost function =  4422625387169178.0
# Iteration = 82900
# Cost function =  4419957228857261.5
# Iteration = 83000
# Cost function =  4417291380817046.5
# Iteration = 83100
# Cost function =  4414627841038229.5
# Iteration = 83200
# Cost function =  4411966607512282.5
# Iteration = 83300
# Cost function =  4409307678232465.5
# Iteration = 83400
# Cost function =  4406651051193805.5
# Iteration = 83500
# Cost function =  4403996724393101.0
# Iteration = 83600
# Cost function =  4401344695828933.0
# Iteration = 83700
# Cost function =  4398694963501650.5
# Iteration = 83800
# Cost function =  4396047525413364.0
# Iteration = 83900
# Cost function =  4393402379567955.5
# Iteration = 84000
# Cost function =  4390759523971080.5
# Iteration = 84100
# Cost function =  4388118956630154.5
# Iteration = 84200
# Cost function =  4385480675554350.5
# Iteration = 84300
# Cost function =  4382844678754603.5
# Iteration = 84400
# Cost function =  4380210964243617.0
# Iteration = 84500
# Cost function =  4377579530035844.5
# Iteration = 84600
# Cost function =  4374950374147493.5
# Iteration = 84700
# Cost function =  4372323494596536.0
# Iteration = 84800
# Cost function =  4369698889402684.0
# Iteration = 84900
# Cost function =  4367076556587410.5
# Iteration = 85000
# Cost function =  4364456494173930.0
# Iteration = 85100
# Cost function =  4361838700187216.0
# Iteration = 85200
# Cost function =  4359223172653975.0
# Iteration = 85300
# Cost function =  4356609909602673.0
# Iteration = 85400
# Cost function =  4353998909063506.5
# Iteration = 85500
# Cost function =  4351390169068418.5
# Iteration = 85600
# Cost function =  4348783687651090.5
# Iteration = 85700
# Cost function =  4346179462846939.5
# Iteration = 85800
# Cost function =  4343577492693130.5
# Iteration = 85900
# Cost function =  4340977775228549.0
# Iteration = 86000
# Cost function =  4338380308493822.5
# Iteration = 86100
# Cost function =  4335785090531306.5
# Iteration = 86200
# Cost function =  4333192119385088.0
# Iteration = 86300
# Cost function =  4330601393100982.5
# Iteration = 86400
# Cost function =  4328012909726531.0
# Iteration = 86500
# Cost function =  4325426667311002.5
# Iteration = 86600
# Cost function =  4322842663905386.5
# Iteration = 86700
# Cost function =  4320260897562401.5
# Iteration = 86800
# Cost function =  4317681366336474.0
# Iteration = 86900
# Cost function =  4315104068283758.5
# Iteration = 87000
# Cost function =  4312529001462122.5
# Iteration = 87100
# Cost function =  4309956163931158.0
# Iteration = 87200
# Cost function =  4307385553752158.0
# Iteration = 87300
# Cost function =  4304817168988134.5
# Iteration = 87400
# Cost function =  4302251007703811.5
# Iteration = 87500
# Cost function =  4299687067965621.5
# Iteration = 87600
# Cost function =  4297125347841701.0
# Iteration = 87700
# Cost function =  4294565845401898.0
# Iteration = 87800
# Cost function =  4292008558717760.5
# Iteration = 87900
# Cost function =  4289453485862546.0
# Iteration = 88000
# Cost function =  4286900624911205.0
# Iteration = 88100
# Cost function =  4284349973940392.5
# Iteration = 88200
# Cost function =  4281801531028458.0
# Iteration = 88300
# Cost function =  4279255294255455.0
# Iteration = 88400
# Cost function =  4276711261703123.0
# Iteration = 88500
# Cost function =  4274169431454901.0
# Iteration = 88600
# Cost function =  4271629801595916.5
# Iteration = 88700
# Cost function =  4269092370212994.5
# Iteration = 88800
# Cost function =  4266557135394637.5
# Iteration = 88900
# Cost function =  4264024095231041.5
# Iteration = 89000
# Cost function =  4261493247814086.5
# Iteration = 89100
# Cost function =  4258964591237340.0
# Iteration = 89200
# Cost function =  4256438123596049.0
# Iteration = 89300
# Cost function =  4253913842987142.0
# Iteration = 89400
# Cost function =  4251391747509225.5
# Iteration = 89500
# Cost function =  4248871835262585.5
# Iteration = 89600
# Cost function =  4246354104349182.0
# Iteration = 89700
# Cost function =  4243838552872652.5
# Iteration = 89800
# Cost function =  4241325178938310.0
# Iteration = 89900
# Cost function =  4238813980653133.0
# Iteration = 90000
# Cost function =  4236304956125770.5
# Iteration = 90100
# Cost function =  4233798103466544.0
# Iteration = 90200
# Cost function =  4231293420787442.0
# Iteration = 90300
# Cost function =  4228790906202114.0
# Iteration = 90400
# Cost function =  4226290557825876.0
# Iteration = 90500
# Cost function =  4223792373775708.0
# Iteration = 90600
# Cost function =  4221296352170245.0
# Iteration = 90700
# Cost function =  4218802491129786.0
# Iteration = 90800
# Cost function =  4216310788776290.5
# Iteration = 90900
# Cost function =  4213821243233372.5
# Iteration = 91000
# Cost function =  4211333852626293.5
# Iteration = 91100
# Cost function =  4208848615081970.0
# Iteration = 91200
# Cost function =  4206365528728983.0
# Iteration = 91300
# Cost function =  4203884591697551.0
# Iteration = 91400
# Cost function =  4201405802119538.5
# Iteration = 91500
# Cost function =  4198929158128470.5
# Iteration = 91600
# Cost function =  4196454657859506.0
# Iteration = 91700
# Cost function =  4193982299449448.5
# Iteration = 91800
# Cost function =  4191512081036750.0
# Iteration = 91900
# Cost function =  4189044000761501.0
# Iteration = 92000
# Cost function =  4186578056765429.0
# Iteration = 92100
# Cost function =  4184114247191903.0
# Iteration = 92200
# Cost function =  4181652570185926.0
# Iteration = 92300
# Cost function =  4179193023894133.0
# Iteration = 92400
# Cost function =  4176735606464799.0
# Iteration = 92500
# Cost function =  4174280316047829.5
# Iteration = 92600
# Cost function =  4171827150794756.5
# Iteration = 92700
# Cost function =  4169376108858743.5
# Iteration = 92800
# Cost function =  4166927188394579.5
# Iteration = 92900
# Cost function =  4164480387558681.0
# Iteration = 93000
# Cost function =  4162035704509088.5
# Iteration = 93100
# Cost function =  4159593137405467.0
# Iteration = 93200
# Cost function =  4157152684409098.5
# Iteration = 93300
# Cost function =  4154714343682886.5
# Iteration = 93400
# Cost function =  4152278113391358.5
# Iteration = 93500
# Cost function =  4149843991700649.5
# Iteration = 93600
# Cost function =  4147411976778516.0
# Iteration = 93700
# Cost function =  4144982066794327.5
# Iteration = 93800
# Cost function =  4142554259919064.0
# Iteration = 93900
# Cost function =  4140128554325319.5
# Iteration = 94000
# Cost function =  4137704948187298.5
# Iteration = 94100
# Cost function =  4135283439680804.0
# Iteration = 94200
# Cost function =  4132864026983255.5
# Iteration = 94300
# Cost function =  4130446708273676.0
# Iteration = 94400
# Cost function =  4128031481732686.0
# Iteration = 94500
# Cost function =  4125618345542514.5
# Iteration = 94600
# Cost function =  4123207297886986.0
# Iteration = 94700
# Cost function =  4120798336951530.0
# Iteration = 94800
# Cost function =  4118391460923165.5
# Iteration = 94900
# Cost function =  4115986667990519.0
# Iteration = 95000
# Cost function =  4113583956343801.5
# Iteration = 95100
# Cost function =  4111183324174822.0
# Iteration = 95200
# Cost function =  4108784769676978.0
# Iteration = 95300
# Cost function =  4106388291045264.0
# Iteration = 95400
# Cost function =  4103993886476251.5
# Iteration = 95500
# Cost function =  4101601554168114.0
# Iteration = 95600
# Cost function =  4099211292320598.0
# Iteration = 95700
# Cost function =  4096823099135043.0
# Iteration = 95800
# Cost function =  4094436972814367.5
# Iteration = 95900
# Cost function =  4092052911563071.0
# Iteration = 96000
# Cost function =  4089670913587238.5
# Iteration = 96100
# Cost function =  4087290977094526.5
# Iteration = 96200
# Cost function =  4084913100294168.0
# Iteration = 96300
# Cost function =  4082537281396980.5
# Iteration = 96400
# Cost function =  4080163518615352.0
# Iteration = 96500
# Cost function =  4077791810163238.5
# Iteration = 96600
# Cost function =  4075422154256170.5
# Iteration = 96700
# Cost function =  4073054549111251.5
# Iteration = 96800
# Cost function =  4070688992947147.5
# Iteration = 96900
# Cost function =  4068325483984099.0
# Iteration = 97000
# Cost function =  4065964020443904.0
# Iteration = 97100
# Cost function =  4063604600549930.0
# Iteration = 97200
# Cost function =  4061247222527106.5
# Iteration = 97300
# Cost function =  4058891884601923.0
# Iteration = 97400
# Cost function =  4056538585002431.5
# Iteration = 97500
# Cost function =  4054187321958240.0
# Iteration = 97600
# Cost function =  4051838093700513.5
# Iteration = 97700
# Cost function =  4049490898461974.0
# Iteration = 97800
# Cost function =  4047145734476895.5
# Iteration = 97900
# Cost function =  4044802599981105.5
# Iteration = 98000
# Cost function =  4042461493211984.0
# Iteration = 98100
# Cost function =  4040122412408462.5
# Iteration = 98200
# Cost function =  4037785355811015.5
# Iteration = 98300
# Cost function =  4035450321661670.0
# Iteration = 98400
# Cost function =  4033117308203997.0
# Iteration = 98500
# Cost function =  4030786313683111.0
# Iteration = 98600
# Cost function =  4028457336345667.0
# Iteration = 98700
# Cost function =  4026130374439865.5
# Iteration = 98800
# Cost function =  4023805426215447.5
# Iteration = 98900
# Cost function =  4021482489923685.5
# Iteration = 99000
# Cost function =  4019161563817397.5
# Iteration = 99100
# Cost function =  4016842646150935.0
# Iteration = 99200
# Cost function =  4014525735180181.5
# Iteration = 99300
# Cost function =  4012210829162556.0
# Iteration = 99400
# Cost function =  4009897926357001.5
# Iteration = 99500
# Cost function =  4007587025024001.0
# Iteration = 99600
# Cost function =  4005278123425567.5
# Iteration = 99700
# Cost function =  4002971219825230.5
# Iteration = 99800
# Cost function =  4000666312488054.0
# Iteration = 99900
# Cost function =  3998363399680624.0
# Iteration = 100000
# Cost function =  3996062479671047.0
# Done with gradient descent at iteration  100001
# Learned weights =  [ 189550.85064805   33351.77385451  166146.06364053  204635.97225403
#  -165545.18790289  -12568.75053142   -1244.37889441   -2031.80337115
#     2117.24642605   -1772.6861494    -1856.36395856   12794.01082457
#     4667.42398104    1143.20614224   -1341.17354129     293.55630032]

# %%
print(matrix_feature)
print()

# %% [markdown]
# ## Hiển thị tác động của L2 penalty

# %% [markdown]
# L2 penalty được đặt tên như vậy vì nó khiến các trọng số có chuẩn L2 nhỏ hơn so với các trường hợp khác. Hãy xem các trọng số lớn bị phạt như thế nào. Chúng ta sẽ xem xét một mô hình đơn giản có 1 đặc trưng:

# %%
simple_features = ['sqft_living']
my_output = 'price'

# %% [markdown]
# Hãy chia thành tập huấn luyện và tập kiểm tra. Đảm bảo dùng `seed=0`:

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(full_data, train_size=0.8, test_size=0.2, random_state=0)

# %% [markdown]
# Trong phần này, chúng ta sẽ chỉ dùng `'sqft_living'` để dự đoán `'price'`. Sử dụng hàm `get_numpy_data` để lấy phiên bản Numpy cảu dữ liệu chỉ với đặc trưng này cho cả `train_data` và `test_data`.

# %%
(simple_feature_matrix, output) = get_numpy_data(train_data, simple_features, my_output)
(simple_test_feature_matrix, test_output) = get_numpy_data(test_data, simple_features, my_output)

# %% [markdown]
# Đặt các tham số cho tối ưu hóa:

# %%
initial_weights = np.array([0., 0.])
step_size = 1e-12
max_iterations=1000

# %% [markdown]
# Trước tiên, chúng ta sẽ xét không có điều chuẩn. Đặt `l2_penalty` thành `0.0` và chạy thuật toán hồi quy Ridge để tìm hiểu các trọng số của mô hình. Gọi trọng số :
#
# `simple_weights_0_penalty`
#
# chúng ta sẽ sử dụng chúng sau.

# %%
l2_penalty = 0.0
simple_weights_0_penalty = ridge_regression_gradient_descent(simple_feature_matrix, output, initial_weights, step_size, l2_penalty, 1000)
# Out:
# Starting gradient descent with l2_penalty = 0.0
# Iteration = 1
# Cost function =  7492352980693717.0
# Iteration = 2
# Cost function =  5443732834808188.0
# Iteration = 3
# Cost function =  4063835449939597.5
# Iteration = 4
# Cost function =  3134372368846771.5
# Iteration = 5
# Cost function =  2508310149584063.0
# Iteration = 6
# Cost function =  2086610880007098.0
# Iteration = 7
# Cost function =  1802565191742774.0
# Iteration = 8
# Cost function =  1611239384833331.0
# Iteration = 9
# Cost function =  1482367284659914.2
# Iteration = 10
# Cost function =  1395562381166147.2
# Iteration = 20
# Cost function =  1219885511283039.0
# Iteration = 30
# Cost function =  1216508222454018.5
# Iteration = 40
# Cost function =  1216443295255467.0
# Iteration = 50
# Cost function =  1216442046328817.8
# Iteration = 60
# Cost function =  1216442021580795.8
# Iteration = 70
# Cost function =  1216442020366912.8
# Iteration = 80
# Cost function =  1216442019605460.5
# Iteration = 90
# Cost function =  1216442018852706.0
# Iteration = 100
# Cost function =  1216442018100119.0
# Iteration = 200
# Cost function =  1216442010574283.5
# Iteration = 300
# Cost function =  1216442003048457.0
# Iteration = 400
# Cost function =  1216441995522639.5
# Iteration = 500
# Cost function =  1216441987996829.5
# Iteration = 600
# Cost function =  1216441980471029.5
# Iteration = 700
# Cost function =  1216441972945237.0
# Iteration = 800
# Cost function =  1216441965419453.5
# Iteration = 900
# Cost function =  1216441957893678.5
# Iteration = 1000
# Cost function =  1216441950367911.8
# Done with gradient descent at iteration  1001
# Learned weights =  [-1.68382078e-01  2.64595376e+02]

# %% [markdown]
# Tiếp theo, hãy xét với điều chuẩn cao. Đặt `l2_penalty` bằng `1e11` và chạy thuật toán hồi quy Ridge để tìm hiểu các trọng số của mô hình. Gọi trọng số:
#
# `simple_weights_high_penalty`
#
# chúng ta sẽ sử dụng chúng sau.

# %%
l2_penalty = 1e11
simple_weights_high_penalty =  ridge_regression_gradient_descent(simple_feature_matrix, output, initial_weights, step_size, l2_penalty, 1000)
# Out:
# Starting gradient descent with l2_penalty = 100000000000.0
# Iteration = 1
# Cost function =  7492352980693717.0
# Iteration = 2
# Cost function =  5668767414760512.0
# Iteration = 3
# Cost function =  4966162001138453.0
# Iteration = 4
# Cost function =  4695456615978694.0
# Iteration = 5
# Cost function =  4591157062537859.0
# Iteration = 6
# Cost function =  4550971653587026.0
# Iteration = 7
# Cost function =  4535488645274578.0
# Iteration = 8
# Cost function =  4529523171698863.0
# Iteration = 9
# Cost function =  4527224688582535.0
# Iteration = 10
# Cost function =  4526339052322166.0
# Iteration = 20
# Cost function =  4525783100988794.0
# Iteration = 30
# Cost function =  4525782106859238.0
# Iteration = 40
# Cost function =  4525781152734926.0
# Iteration = 50
# Cost function =  4525780198613897.0
# Iteration = 60
# Cost function =  4525779244493267.0
# Iteration = 70
# Cost function =  4525778290373037.0
# Iteration = 80
# Cost function =  4525777336253206.0
# Iteration = 90
# Cost function =  4525776382133775.0
# Iteration = 100
# Cost function =  4525775428014742.0
# Iteration = 200
# Cost function =  4525765886846373.0
# Iteration = 300
# Cost function =  4525756345717926.0
# Iteration = 400
# Cost function =  4525746804629403.0
# Iteration = 500
# Cost function =  4525737263580802.0
# Iteration = 600
# Cost function =  4525727722572125.0
# Iteration = 700
# Cost function =  4525718181603369.0
# Iteration = 800
# Cost function =  4525708640674536.0
# Iteration = 900
# Cost function =  4525699099785624.0
# Iteration = 1000
# Cost function =  4525689558936635.0
# Done with gradient descent at iteration  1001
# Learned weights =  [  9.80132073 125.07001848]

# %% [markdown]
# Code này sẽ vẽ biểu đồ 2 mô hình đã tìm hiểu. (Đường màu xanh dương biểu thị mô hình không điều chuẩn, đường màu đỏ biểu thị mô hình với điều chuẩn cao).

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(simple_feature_matrix[:, 1:], output,'k.',
         simple_feature_matrix[:, 1:], predict_output(simple_feature_matrix, simple_weights_0_penalty),'b-',
         simple_feature_matrix[:, 1:], predict_output(simple_feature_matrix, simple_weights_high_penalty),'r-')
# Out:
# [<matplotlib.lines.Line2D at 0x7bafed0845b0>,
#  <matplotlib.lines.Line2D at 0x7bafed084580>,
#  <matplotlib.lines.Line2D at 0x7bafed084790>]

# %% [markdown]
# **Tại sao `[:, 1:]`? ¯\\\_(ツ)\_/¯ Chúng ta cần tìm hiểu** +> vì feature đầu tiên là hằng số 1

# %% [markdown]
# Tính RSS trên dữ liệu KIỂM TRA cho ba tập hợp trọng số sau:
# 1. Các trọng số ban đầu (các số 0)
# 2. Các trọng số đã tìm hiểu khi không điều chuẩn
# 3. Các trọng số đã tìm hiểu có điều chuẩn cao
#
# Những trọng số nào thể hiện tốt nhất?

# %%
(simple_test_feature_matrix, test_output) = get_numpy_data(test_data, simple_features, my_output)

# %%
print(simple_test_feature_matrix)
print(test_output)
# Out:
# [[   1 1430]
#  [   1 4670]
#  [   1 1440]
#  ...
#  [   1 1360]
#  [   1  950]
#  [   1 1640]]
# [ 297000. 1578000.  562100. ...  369950.  300000.  575950.]

# %%
# Một lần nữa thực hiện trong ba tập hợp
error_0 = predict_output(simple_test_feature_matrix, initial_weights) -test_output
RSS_error_0 = error_0@(error_0.T)

error_low_penalty = predict_output(simple_test_feature_matrix, simple_weights_0_penalty) -test_output
RSS_error_low_penalty = error_low_penalty@(error_low_penalty.T)

error_high_penalty = predict_output(simple_test_feature_matrix, simple_weights_high_penalty) -test_output
RSS_error_high_penalty = error_high_penalty@(error_high_penalty.T)

print("with {} the RSS is: {}".format(initial_weights, RSS_error_0))
print("with {} the RSS is: {}".format(simple_weights_0_penalty, RSS_error_low_penalty))
print("with {} the RSS is: {}".format(simple_weights_high_penalty, RSS_error_high_penalty))
# Out:
# with [0. 0.] the RSS is: 1724972157778353.0
# with [-1.68382078e-01  2.64595376e+02] the RSS is: 267785724030024.94
# with [  9.80132073 125.07001848] the RSS is: 650754956310344.0

# %%
# Hoặc thực hiện trong một tập hợp

# %%
# Trong cả hai trường hợp, hãy để ý vị trí của 'constant'

# %% [markdown]
# ***QUIZ***
# 1. Giá trị của hệ số cho `sqft_living` đã tìm hiểu khi không điều chuẩn (làm tròn tới chữ số thập phân thứ nhất) là bao nhiêu? Giá trị của hệ số cho `sqft_living` đã tìm hiểu với điều chuẩn cao (làm tròn tới chữ số thập phân thứ nhất) là bao nhiêu?
# 2. So sánh hai đường khớp với điều chuẩn cao và không điều chuẩn, đường nào dốc hơn?
# 3. RSS trên dữ liệu KIỂM TRA cho từng tập hợp trọng số trên (ban đầu, không điều chuẩn, điều chuẩn cao) là bao nhiêu?

# %%
"""
Tra loi:
1.Với không điều chuẩn thì giá trị hệ số sqft_living là 264.5, với điều chuẩn cao thì là 125
2.Đường không điều chuẩn dốc hơn
3. RSS với ban đầu, không điều chuẩn và có điều chuẩn là:
with [0. 0.] the RSS is: 1724972157778353.0
with [-1.68382078e-01  2.64595376e+02] the RSS is: 267785724030024.94
with [  9.80132073 125.07001848] the RSS is: 650754956310344.0
"""

# %% [markdown]
# ## Chạy hồi quy đa biến với L2 penalty

# %% [markdown]
# Xét mô hình với 2 đặc trưng: `['sqft_living', 'sqft_living15']`.

# %% [markdown]
# Trước tiên, tạo các phiên bản Numpy của dữ liệu huấn luyện và kiểm tra với 2 đặc trưng đó.

# %%
model_features = ['sqft_living', 'sqft_living15'] # sqft_living15 là diện tích trung bình cho 15 hàng xóm gần nhất.
my_output = 'price'
(feature_matrix, output) = get_numpy_data(train_data, model_features, my_output)
(test_feature_matrix, test_output) = get_numpy_data(test_data, model_features, my_output)

# %% [markdown]
# Chúng ta cần khởi tạo lại các trọng số do có thêm một tham số. Hãy thiết lập kích thước bước và số lần lặp tối đa.

# %%
initial_weights = np.array([0.0,0.0,0.0])
step_size = 1e-12
max_iterations = 1000

# %% [markdown]
# Trước tiên, xét không điều chuẩn. Đặt `l2_penalty` thành `0.0` và chạy thuật toán hồi quy Ridge để tìm hiểu trọng số của mô hình. Gọi trọng số:
#
# `multiple_weights_0_penalty`

# %%
# tương tự
l2_penalty = 0.0
multiple_weights_0_penalty =  ridge_regression_gradient_descent(feature_matrix, output, initial_weights, step_size, l2_penalty, 1000)
# Out:
# Starting gradient descent with l2_penalty = 0.0
# Iteration = 1
# Cost function =  7492352980693717.0
# Iteration = 2
# Cost function =  4100015537310633.0
# Iteration = 3
# Cost function =  2559550924574727.0
# Iteration = 4
# Cost function =  1859797380721437.8
# Iteration = 5
# Cost function =  1541711552960680.8
# Iteration = 6
# Cost function =  1396898662272782.5
# Iteration = 7
# Cost function =  1330752397328856.8
# Iteration = 8
# Cost function =  1300323694547045.5
# Iteration = 9
# Cost function =  1286114647925854.5
# Iteration = 10
# Cost function =  1279273617662949.5
# Iteration = 20
# Cost function =  1267419439007469.5
# Iteration = 30
# Cost function =  1261408974114915.5
# Iteration = 40
# Cost function =  1256075260691903.0
# Iteration = 50
# Cost function =  1251340611311291.0
# Iteration = 60
# Cost function =  1247137740623208.5
# Iteration = 70
# Cost function =  1243406921150493.8
# Iteration = 80
# Cost function =  1240095133792398.0
# Iteration = 90
# Cost function =  1237155314363555.5
# Iteration = 100
# Cost function =  1234545684759230.2
# Iteration = 200
# Cost function =  1220186473013792.5
# Iteration = 300
# Cost function =  1215824193814159.0
# Iteration = 400
# Cost function =  1214498941566952.2
# Iteration = 500
# Cost function =  1214096325605182.0
# Iteration = 600
# Cost function =  1213974002748659.8
# Iteration = 700
# Cost function =  1213936831783619.5
# Iteration = 800
# Cost function =  1213925529612668.2
# Iteration = 900
# Cost function =  1213922086274873.2
# Iteration = 1000
# Cost function =  1213921030418245.0
# Done with gradient descent at iteration  1001
# Learned weights =  [ -0.36143245 245.10459435  21.88553589]

# %% [markdown]
# Tiếp theo, xét điều chuẩn cao. Đặt `l2_penalty` thành `1e11` và chạy thuật toán hồi quy Ridge để tìm hiểu trọng số của mô hình. Gọi trọng số:
#
# `multiple_weights_high_penalty`

# %%
# tiếp tục
l2_penalty = 1e11
multiple_weights_high_penalty =  ridge_regression_gradient_descent(feature_matrix, output, initial_weights, step_size, l2_penalty, 1000)
# Out:
# Starting gradient descent with l2_penalty = 100000000000.0
# Iteration = 1
# Cost function =  7492352980693717.0
# Iteration = 2
# Cost function =  4505351315995475.0
# Iteration = 3
# Cost function =  3834583288398276.0
# Iteration = 4
# Cost function =  3683836193524818.0
# Iteration = 5
# Cost function =  3649883287712292.5
# Iteration = 6
# Cost function =  3642189242934818.0
# Iteration = 7
# Cost function =  3640416281547277.0
# Iteration = 8
# Cost function =  3639989348600833.0
# Iteration = 9
# Cost function =  3639875240690509.0
# Iteration = 10
# Cost function =  3639838090592815.5
# Iteration = 20
# Cost function =  3639801889882883.0
# Iteration = 30
# Cost function =  3639801135780288.0
# Iteration = 40
# Cost function =  3639800678437837.0
# Iteration = 50
# Cost function =  3639800224043187.0
# Iteration = 60
# Cost function =  3639799769677959.0
# Iteration = 70
# Cost function =  3639799315313164.0
# Iteration = 80
# Cost function =  3639798860948515.0
# Iteration = 90
# Cost function =  3639798406584009.0
# Iteration = 100
# Cost function =  3639797952219646.5
# Iteration = 200
# Cost function =  3639793408583893.5
# Iteration = 300
# Cost function =  3639788864962452.5
# Iteration = 400
# Cost function =  3639784321355323.0
# Iteration = 500
# Cost function =  3639779777762506.0
# Iteration = 600
# Cost function =  3639775234184001.0
# Iteration = 700
# Cost function =  3639770690619808.0
# Iteration = 800
# Cost function =  3639766147069927.0
# Iteration = 900
# Cost function =  3639761603534357.5
# Iteration = 1000
# Cost function =  3639757060013099.5
# Done with gradient descent at iteration  1001
# Learned weights =  [ 6.77018948 91.93393065 78.75003338]

# %% [markdown]
# Tính RSS trên dữ liệu KIỂM TRA cho ba tập hợp trọng số sau:
# 1. Trọng số ban đầu (các số 0)
# 2. Trọng số đã tìm hiểu không điều chuẩn
# 3. Trọng số đã tìm hiểu với điều chuẩn cao
#
# Các trọng số nào thực hiện tốt nhất?

# %%
# Thấy rồi chứ?

error_mul_0 = predict_output(test_feature_matrix, initial_weights) -test_output
RSS_mul_error_0 = error_mul_0@(error_mul_0.T)

error_mul_weights_0 = predict_output(test_feature_matrix, multiple_weights_0_penalty) -test_output
RSS_mul_error_low = error_mul_weights_0@(error_mul_weights_0.T)

error_mul_high = predict_output(test_feature_matrix, multiple_weights_high_penalty) -test_output
RSS_mul_error_high = error_mul_high@(error_mul_high.T)

print("with {} the RSS is: {}".format(initial_weights, RSS_mul_error_0))
print("with {} the RSS is: {}".format(multiple_weights_0_penalty, RSS_mul_error_low))
print("with {} the RSS is: {}".format(multiple_weights_high_penalty, RSS_mul_error_high))
# Out:
# with [0. 0. 0.] the RSS is: 1724972157778353.0
# with [ -0.36143245 245.10459435  21.88553589] the RSS is: 266037696400104.0
# with [ 6.77018948 91.93393065 78.75003338] the RSS is: 462809236167559.4

# %%
#=====> trọng số của l2_penalty = 0 thực hiện tốt nhất

# %%
# Cũng hãy chú ý 'constant'

# %%
# Lần này không có fit_intercept=True có sẵn

# %% [markdown]
# Dự đoán giá nhà cho ngôi nhà thứ 5 trong tập kiểm tra sử dụng mô hình không điều chuẩn và mô hình có điều chuẩn cao. (Nhớ rằng Python bắt đầu lập chỉ mục từ 0). Dự đoán cách giá thực tế bao nhiêu? Các trọng số nào thực hiện tốt nhất với ngôi nhà thứ nhất?

# %%
# Đây cũng là quiz
house_5_feature = test_feature_matrix[4,:]
hou5e_5_price_true = output[4]
predict_house_5_low_weight = predict_output(house_5_feature, multiple_weights_0_penalty)
predict_house_5_high_weight = predict_output(house_5_feature, multiple_weights_high_penalty)
print(hou5e_5_price_true)
print("values of 5th house with l2_penalty equals to {} is: {}".format(multiple_weights_0_penalty, predict_house_5_low_weight))
print("values of 5th house with l2_penalty equals to {} is: {}".format(multiple_weights_high_penalty, predict_house_5_high_weight))
# Out:
# 670000.0
# values of 5th house with l2_penalty equals to [ -0.36143245 245.10459435  21.88553589] is: 832832.9561687661
# values of 5th house with l2_penalty equals to [ 6.77018948 91.93393065 78.75003338] is: 484506.75111491524

# %%
# Nên hãy vô cùng cẩn thận

#=>>>>>>>>>>>>>> trọng số với L2_penalty tốt hơn

# %% [markdown]
# ***QUIZ***
# 1. Giá trị của hệ số cho `sqft_living` đã tìm hiểu khi không điều chuẩn (làm tròn tới chữ số thập phân thứ nhất) là bao nhiêu? Giá trị của hệ số cho `sqft_living` đã tìm hiểu với điều chuẩn cao (làm tròn tới chữ số thập phân thứ nhất) là bao nhiêu?
# 2. RSS trên dữ liệu KIỂM TRA cho từng tập hợp trọng số trên (ban đầu, không điều chuẩn, điều chuẩ cao) là bao nhiêu?
# 3. Chúng ta đưa ra dự đoán cho ngôi nhà thứ năm trong tập kiểm tra sử dụng hai tập hợp trọng số (không điều chuẩn với điều chuẩn cao). Trọng số nào cho dự đoán sát hơn <u>với ngôi nhà đó</u>?

# %%
"""
1. Giá trị hệ số sqft_living không điều chuẩn: 245.1, ,có điều chuẩn cao: 91.9
2. Rss với weights ban đầu, không điều chuẩn, có điều chuẩn cao:
with [0. 0. 0.] the RSS is: 1724972157778353.0
with [ -0.36143245 245.10459435  21.88553589] the RSS is: 266037696400104.0
with [ 6.77018948 91.93393065 78.75003338] the RSS is: 462809236167559.4
3. Trọng số không điều chuẩn mang lại dự đoán sát hơn
